# %%
import os
os.chdir('../')

# %%
import AUDLclasses
AUDL = AUDLclasses.League()

# %%
AUDL.add_teams(games=False,players=False,stats=False)

# %%
AUDL.Teams[219001].add_games()
AUDL.Teams[207003].add_games()
AUDL.Teams[210001].add_games()
AUDL.Teams[253001].add_games()
AUDL.Teams[224002].add_games()
# Out:
# --------------
# Mechanix
# ---------------
# Cincinnati Revolution
# 5/2/14
# Chicago Wildfire
# 5/3/14
# Indianapolis AlleyCats
# 5/17/14
# Chicago Wildfire
# 6/7/14
# Minnesota Wind Chill
# 6/27/14
# Madison Radicals
# 6/28/14
# Cincinnati Revolution
# 7/5/14
# Minnesota Wind Chill
# 4/12/14
# Madison Radicals
# 4/19/14
# Indianapolis AlleyCats
# 4/26/14
# Cincinnati Revolution
# 5/10/14
# Minnesota Wind Chill
# 5/25/14
# Chicago Wildfire
# 5/31/14
# Indianapolis AlleyCats
# 6/14/14
# --------------
# Wildfire
# ---------------
# Cincinnati Revolution
# 4/18/14
# Indianapolis AlleyCats
# 4/19/14
# Minnesota Wind Chill
# 5/17/14
# Madison Radicals
# 5/24/14
# Detroit Mechanix
# 5/31/14
# Madison Radicals
# 6/20/14
# Minnesota Wind Chill
# 6/21/14
# Minnesota Wind Chill
# 4/13/14
# Cincinnati Revolution
# 4/26/14
# Detroit Mechanix
# 5/3/14
# Indianapolis AlleyCats
# 5/9/14
# Madison Radicals
# 5/23/14
# Detroit Mechanix
# 6/7/14
# Cincinnati Revolution
# 6/28/14
# --------------
# ...

# %%
games = AUDL.Teams[210001].Games
print games.keys()[0]
for game in games:
    print games[game].date,
    print games[game],
    print game
# Out:
# 4/13/14
# 4/13/14 <AUDLclasses.Game instance at 0x39b4cb0> 4/13/14
# 5/17/14 <AUDLclasses.Game instance at 0x39b4b90> 5/17/14
# 6/21/14 <AUDLclasses.Game instance at 0x39b4c68> 6/21/14
# 5/25/14 <AUDLclasses.Game instance at 0x39b4488> 5/25/14
# 4/25/14 <AUDLclasses.Game instance at 0x39b71b8> 4/25/14
# 6/27/14 <AUDLclasses.Game instance at 0x39b4290> 6/27/14
# 6/14/14 <AUDLclasses.Game instance at 0x39b7170> 6/14/14
# 5/10/14 <AUDLclasses.Game instance at 0x39b70e0> 5/10/14
# 4/12/14 <AUDLclasses.Game instance at 0x39b4368> 4/12/14
# 6/7/14 <AUDLclasses.Game instance at 0x39b7290> 6/7/14
# 5/4/14 <AUDLclasses.Game instance at 0x39b7200> 5/4/14
# 5/31/14 <AUDLclasses.Game instance at 0x39b7248> 5/31/14
# 5/24/14 <AUDLclasses.Game instance at 0x39b7128> 5/24/14
# 5/9/14 <AUDLclasses.Game instance at 0x39b7098> 5/9/14

# %%
games = AUDL.Teams[219001].Games
for game in games:
    print games[game].date,
    print games[game]
# Out:
# 7/5/14 <AUDLclasses.Game instance at 0x39b4320>
# 4/19/14 <AUDLclasses.Game instance at 0x39b43b0>
# 5/10/14 <AUDLclasses.Game instance at 0x39b4440>
# 5/17/14 <AUDLclasses.Game instance at 0x39b4200>
# 5/2/14 <AUDLclasses.Game instance at 0x39b4170>
# 6/28/14 <AUDLclasses.Game instance at 0x39b42d8>
# 6/27/14 <AUDLclasses.Game instance at 0x39b4290>
# 6/14/14 <AUDLclasses.Game instance at 0x39b4518>
# 4/12/14 <AUDLclasses.Game instance at 0x39b4368>
# 6/7/14 <AUDLclasses.Game instance at 0x39b4248>
# 5/3/14 <AUDLclasses.Game instance at 0x39b41b8>
# 5/25/14 <AUDLclasses.Game instance at 0x39b4488>
# 4/26/14 <AUDLclasses.Game instance at 0x39b43f8>
# 5/31/14 <AUDLclasses.Game instance at 0x39b44d0>

# %%
date = unicode('5/9/14')
print AUDL.Teams[224002].Games[date]
# Out:
# 4/12/13
# 5/9/14
# <AUDLclasses.Game instance at 0x39b7098>
